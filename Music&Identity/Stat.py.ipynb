# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin
import statsmodels.formula.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
music_m = pd.read_excel("music_updated_2.xlsx", sheet_name = "numerical_results")
music_c = pd.read_excel("music_updated_2.xlsx", sheet_name = "survey_results")

# %%
music_m.head()
# Out:
#    ResponseID                  Q0    Q1             Q2   Q3  Q4A  Q4B  Q4C  \
# 0         1.0 2022-08-27 19:29:02  18.0        Spotify  3.0  1.0  1.0  1.0
# 1         2.0 2022-08-27 19:57:31  63.0        Pandora  1.5  1.0  0.0  0.0
# 2         3.0 2022-08-27 21:28:18  18.0        Spotify  4.0  0.0  0.0  0.0
# 3         4.0 2022-08-27 21:40:40  61.0  YouTube Music  2.5  1.0  0.0  1.0
# 4         5.0 2022-08-27 21:54:47  18.0        Spotify  4.0  1.0  0.0  0.0
#
#                 Q5A  Q5B  ...  Q8N  Q8O  Q8P  Q9A  Q9B   Q9C  Q9D  Q10  Q00  \
# 0             Latin  1.0  ...  4.0  1.0  3.0  3.0  0.0   1.0  0.0  NaN    1
# 1              Rock  1.0  ...  2.0  4.0  2.0  7.0  2.0   2.0  1.0  NaN    1
# 2  Video game music  0.0  ...  2.0  2.0  4.0  7.0  7.0  10.0  2.0  1.0    1
# 3              Jazz  1.0  ...  1.0  1.0  1.0  9.0  7.0   3.0  3.0  2.0    1
# 4               R&B  1.0  ...  4.0  1.0  2.0  7.0  2.0   5.0  9.0  2.0    1
#
#    Q11
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0
#
# ...

# %%
music_m.columns[13:28]
# Out:
# Index(['Q8B', 'Q8C', 'Q8D', 'Q8E', 'Q8F', 'Q8G', 'Q8H', 'Q8I', 'Q8J', 'Q8K',
#        'Q8L', 'Q8M', 'Q8N', 'Q8O', 'Q8P'],
#       dtype='object')

# %%
music_m["Q8A"].describe()
# Out:
# count    736.000000
# mean       2.335598
# std        0.988442
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Q8A, dtype: float64

# %%
for i in music_m.columns[13:28]:
    x = music_m[i].describe()
    print(x)
# Out:
# count    736.000000
# mean       1.817935
# std        0.922584
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: Q8B, dtype: float64
# count    736.000000
# mean       2.023098
# std        1.048878
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Q8C, dtype: float64
# count    736.000000
# mean       2.012228
# std        1.009405
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: Q8D, dtype: float64
# count    736.000000
# mean       1.381793
# std        0.701520
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: Q8E, dtype: float64
# count    736.000000
# mean       2.384511
# std        1.031598
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# ...

# %%
pd.crosstab(music_c["Q8A"], music_c["Q4B"])
# Out:
# Q4B               No  Yes
# Q8A
# Never            131   37
# Rarely           194   64
# Sometimes        130   69
# Very frequently   42   65

# %%
for i in music_c.columns[13:28]:
    x = pd.crosstab(music_c[i], music_c["Q4B"])
    y = stats.chi2_contingency(x)
    print(y)
# Out:
# (4.8592785065070325, 0.18239627035755787, 3, array([[230.84699454, 109.15300546],
#        [157.51912568,  74.48087432],
#        [ 75.3647541 ,  35.6352459 ],
#        [ 33.26912568,  15.73087432]]))
# (6.637620411648184, 0.08439026768377368, 3, array([[206.40437158,  97.59562842],
#        [131.71857923,  62.28142077],
#        [ 98.44945355,  46.55054645],
#        [ 60.42759563,  28.57240437]]))
# (0.8767362316394851, 0.8310379498365877, 3, array([[196.21994536,  92.78005464],
#        [149.3715847 ,  70.6284153 ],
#        [ 98.44945355,  46.55054645],
#        [ 52.95901639,  25.04098361]]))
# (5.55925529795255, 0.13513713917186235, 3, array([[360.52868852, 170.47131148],
#        [ 91.65983607,  43.34016393],
#        [ 35.30601093,  16.69398907],
#        [  9.50546448,   4.49453552]]))
# (22.34275832316174, 5.53496199922457e-05, 3, array([[121.53415301,  57.46584699],
#        [145.29781421,  68.70218579],
#        [147.33469945,  69.66530055],
# ...

# %%
z = pd.crosstab(music_c["Q8A"], music_c["Q4B"])

# %%
stats.chi2_contingency[z]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6e899943f657> in <module>
# ----> 1 stats.chi2_contingency[z]
#
# TypeError: 'function' object is not subscriptable

# %%
music_m["Q8P"].describe()

# %%
stats.chi2_contingency(pd.crosstab(music_c["Q8P"], music_c["Q4B"]))

# %%
formula1 = "Q8P ~ Q4B"
model1 = sm.ols(formula = formula1, data = music_m)
fitted = model1.fit()
fitted.summary()

# %%
storage = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q4C"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage.append
    print(fitted.summary())

# %%
storage = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q6"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     9.092
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):            0.00266
# Time:                        13:51:55   Log-Likelihood:                -1025.2
# No. Observations:                 732   AIC:                             2054.
# Df Residuals:                     730   BIC:                             2064.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2104      0.054     40.719      0.000       2.104       2.317
# ...

# %%
storage_mc = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q11"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage_mc.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     44.36
# Date:                Sun, 26 Mar 2023   Prob (F-statistic):           5.37e-11
# Time:                        21:52:09   Log-Likelihood:                -1007.4
# No. Observations:                 732   AIC:                             2019.
# Df Residuals:                     730   BIC:                             2028.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.1552      0.045     48.380      0.000       2.068       2.243
# ...

# %%
storage_a = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q1"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage_a.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     7.417
# Date:                Sun, 26 Mar 2023   Prob (F-statistic):            0.00661
# Time:                        21:53:16   Log-Likelihood:                -1030.6
# No. Observations:                 735   AIC:                             2065.
# Df Residuals:                     733   BIC:                             2074.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.1291      0.084     25.275      0.000       1.964       2.294
# ...

# %%
storage_ac = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q1" + " + Q4C" + " + Q1:Q4C"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage_ac.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     5.524
# Date:                Thu, 20 Jul 2023   Prob (F-statistic):           0.000939
# Time:                        23:23:26   Log-Likelihood:                -1025.1
# No. Observations:                 734   AIC:                             2058.
# Df Residuals:                     730   BIC:                             2077.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0292      0.094     21.511      0.000       1.844       2.214
# ...

# %%
storage_ai = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q1" + " + Q4B"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage_ai.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     31.36
# Date:                Mon, 27 Mar 2023   Prob (F-statistic):           8.64e-14
# Time:                        00:10:26   Log-Likelihood:                -997.87
# No. Observations:                 731   AIC:                             2002.
# Df Residuals:                     728   BIC:                             2016.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8728      0.088     21.213      0.000       1.699       2.046
# ...

# %%
storage_am = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q1" + " + Q11"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage_am.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     29.85
# Date:                Mon, 27 Mar 2023   Prob (F-statistic):           3.47e-13
# Time:                        00:12:41   Log-Likelihood:                -999.26
# No. Observations:                 731   AIC:                             2005.
# Df Residuals:                     728   BIC:                             2018.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8565      0.090     20.691      0.000       1.680       2.033
# ...

# %%
storage_afm = []
for i in music_m.columns[12:28]:
    x = str(i) + " ~ Q1" + " + Q6"
    model1 = sm.ols(formula = x, data = music_m)
    fitted = model1.fit()
    storage_afm.append
    print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q8A   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     9.968
# Date:                Mon, 17 Jul 2023   Prob (F-statistic):           5.36e-05
# Time:                        01:38:07   Log-Likelihood:                -1018.9
# No. Observations:                 731   AIC:                             2044.
# Df Residuals:                     728   BIC:                             2058.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9430      0.098     19.806      0.000       1.750       2.136
# ...

# %%
v = music_m[['Q11','Q1', 'Q6', 'Q4B', 'Q4C']]
w = music_m[['Q11', 'Q1']]
x = music_m[['Q6', 'Q1']]
y = music_m[['Q4B', 'Q1']]
z = music_m[['Q4C', 'Q1']]

# %%
v = v.dropna()
w = w.dropna()
x = x.dropna()
y = y.dropna()
z = z.dropna()
letters = [w,x,y,z]

# %%
vif_data = pd.DataFrame()

# %%
vif_data['feature'] = v.columns

# %%
vif_data['VIF'] = [variance_inflation_factor(v.values, i)
                           for i in range(len(v.columns))]
print(vif_data)
# Out:
#   feature        VIF
# 0     Q11  13.106056
# 1      Q1   1.854385
# 2      Q6   1.710297
# 3     Q4B   9.556700
# 4     Q4C   2.254863

# %%
# Out:
#   feature       VIF
# 0     Q11  1.331631
# 1      Q1  1.331631
