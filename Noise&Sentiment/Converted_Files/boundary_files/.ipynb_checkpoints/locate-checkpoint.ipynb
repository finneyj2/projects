# %%
library(sf)
library(ggplot2)
# Out:
# ...
# package 'sf' was built under R version 4.3.3
# Linking to GEOS 3.11.2, GDAL 3.8.2, PROJ 9.3.1; sf_use_s2() is TRUE
# ...
# package 'ggplot2' was built under R version 4.3.3

# %%
my_sf <- st_read(system.file("/Noise&Sentiment/conus_shp/tractresultAL.shp", package ="sf"))
my_sf
# Out:
# Error:
# `dsn` must point to a source, not an empty string.
# Traceback:
# 1. st_read(system.file("/Noise&Sentiment/conus_shp/tractresultAL.shp", package
# 2. st_read.character(system.file("/Noise&Sentiment/conus_shp/tractresultAL.shp
# Error in eval(expr, envir = envir, enclos = enclos):
# object 'my_sf' not found
# Traceback:

# %%
# Out:
# Simple feature collection with 1436 features and 25 fields
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: 704900.9 ymin: 824495.6 xmax: 1044933 ymax: 1376504
# Projected CRS: USA_Contiguous_Albers_Equal_Area_Conic_USGS_version
# # A tibble: 1,436 × 26
#    GEOID     NAME  variabl estimat   moe cvrg_ll covrg_n cv_4050 cv_5060 cv_6070
#    <chr>     <chr> <chr>     <dbl> <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
#  1 01001020… Cens… B01003…    1941   390  10979.  10106.   316.     458.    94.8
#  2 01001020… Cens… B01003…    1757   310   3698.   3277.   155.     254.    11.7
#  3 01001020… Cens… B01003…    3694   570   5976.   5360.   223.     316.    75.5
#  4 01001020… Cens… B01003…    3539   500   7073.   6194.   252.     308.   313.
#  5 01001020… Cens… B01003…    4306   662   6911.   5831.   328.     478.   220.
#  6 01001020… Cens… B01003…    3100   531   2363.   2070.    89.6    130.    66.2
# ...

# %%
library(ggplot2)
# Out:
# ...
# package 'ggplot2' was built under R version 4.3.3

# %%
ggplot(my_sf) +
  geom_sf(fill = "#69b3a2", color = "white") +
  theme_void()

# %%
x <- 32.525772
y <- -86.703052
