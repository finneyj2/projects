# %%
import pandas as pd
import psycopg2
df_property_1 = pd.read_csv("cleaned1_property_sales.csv")
# Out:
# C:\Users\jahli\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_property_1 = df_property_1.drop(columns = ['PROPERTyCITY'])

# %%
c = conn.cursor()
df_property_1
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 0       1075F00108000000            4720.0
# 1       0011A00237000000               0.0
# 2       0011J00047000000            1903.0
# 3       0113B00029000000             479.0
# 4       0119S00024000000            5418.0
# ...                  ...               ...              ...
# 307751  0424D00020000000               0.0
# 307752  0115B00050000000             466.0
# 307753  0028P00027000000             300.0
# 307754  0613B00301000000            1230.0
# 307755  0383B00358000000             901.0
#
#        PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 0                     NaN             HIGHPOINT                 DR
# 1                     NaN               LOMBARD                 ST
# 2                     NaN                FORBES                AVE
# 3                     NaN             ROOSEVELT                AVE
# 4                     NaN              CARNEGIE                 ST
# ...

# %%
df_property_1 = df_property_1.drop(columns = ['Unnamed: 0'])

# %%
df_property_1.to_csv(r'C:\Users\jahli\Projects\Property_sale_analyses\sql_property_sales.csv', index = False, header = True)

# %%
conn = psycopg2.connect(dbname = "propertysales", user = "postgres", host = "127.0.0.1", port = "5432")
cur = conn.cursor()
print("Opened database successfully")
# Out:
# Opened database successfully

# %%
cur.execute("rollback;")

# %%
cur.execute("COPY propertysales FROM 'C:/Users/Public/Documents' WITH (FORMAT CSV, HEADER);")
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# <ipython-input-19-fef37bee1d77> in <module>
# ----> 1 cur.execute("COPY propertysales FROM 'C:/Users/Public/Documents' WITH (FORMAT CSV, HEADER);")
#
# InsufficientPrivilege: could not open file "C:/Users/Public/Documents" for reading: Permission denied
# HINT:  COPY FROM instructs the PostgreSQL server process to read a file. You may want a client-side facility such as psql's \copy.
