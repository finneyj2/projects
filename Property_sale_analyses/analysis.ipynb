# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import researchpy as rp
import scipy.stats as stats
from datetime import datetime

df_property_1 = pd.read_csv("cleaned1_property_sales.csv")
# Out:
# C:\Users\jahli\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_property_1[["PRICE", "PROPERTYCITY"]].groupby("PROPERTYCITY").describe()
# Out:
#                PRICE                                                     \
#                count           mean            std       min        25%
# PROPERTYCITY
# ALLISON PARK  4828.0  190789.598234  239543.214139       0.0       1.00
# AMBRIDGE       226.0   60345.964602   62735.115313       0.0       1.00
# ASPINWALL        2.0  226505.500000   65910.130181  179900.0  203202.75
# BADEN          201.0  365204.870647  488304.534348       0.0       1.00
# BAIRDFORD       83.0   54289.349398   56398.264136       0.0    1762.00
# ...              ...            ...            ...       ...        ...
# WEST VIEW        1.0       1.000000            NaN       1.0       1.00
# WEXFORD       6270.0  341020.960848  887984.357268       0.0  134600.00
# WHITE OAK        1.0       1.000000            NaN       1.0       1.00
# WILMERDING     518.0   52401.478764  255650.493060       0.0      10.00
# WITAKER          1.0      10.000000            NaN      10.0      10.00
#
#
# ...

# %%
df_property_1.groupby("PROPERTYCITY").count()
# Out:
#               Unnamed: 0  PARID  PROPERTYHOUSENUM  PROPERTYFRACTION  \
# PROPERTYCITY
# ALLISON PARK        4828   4828              4828              4828
# AMBRIDGE             226    226               226               226
# ASPINWALL              2      2                 2                 2
# BADEN                201    201               201               201
# BAIRDFORD             83     83                83                83
# ...                  ...    ...               ...               ...
# WEST VIEW              1      1                 1                 1
# WEXFORD             6270   6270              6270              6270
# WHITE OAK              1      1                 1                 1
# WILMERDING           518    518               518               518
# WITAKER                1      1                 1                 1
#
#               PROPERTYADDRESSDIR  PROPERTYADDRESSSTREET  PROPERTYADDRESSSUF  \
# PROPERTYCITY
# ...

# %%
df_property_1[["PRICE", "PROPERTYCITY", "SALEDATE"]].groupby(pd.Grouper(freq='Y'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-dc9d1a73848f> in <module>
# ----> 1 df_property_1[["PRICE", "PROPERTYCITY", "SALEDATE"]].groupby(pd.Grouper(freq='Y'))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6722             squeeze=squeeze,
#    6723             observed=observed,
# -> 6724             dropna=dropna,
#    6725         )
#    6726
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
#     569             )
#     570
#
# ...

# %%
init_date_1 = datetime(2012, 1, 1)
init_date_2 = datetime(2013, 1, 1)
fin_date_1 = datetime(2020, 1, 1)
fin_date_2 = datetime(2021, 1, 1)
df_property_1["SALEDATE2"] = pd.to_datetime(df_property_1["SALEDATE"])
between_init = (df_property_1["SALEDATE2"] > init_date_1) & (df_property_1["SALEDATE2"] < init_date_2)
between_final = (df_property_1["SALEDATE2"] > fin_date_1) & (df_property_1["SALEDATE2"] < fin_date_2)

# %%
df_property_1["SALEDATE2"].sort_values(ascending=True)
# Out:
# 29810    2012-01-01
# 12258    2012-01-01
# 671      2012-01-01
# 670      2012-01-01
# 669      2012-01-01
#             ...
# 255444   2020-11-16
# 291157   2020-11-16
# 257246   2020-11-19
# 295358   2020-11-19
# 279904   2020-11-23
# Name: SALEDATE2, Length: 307756, dtype: datetime64[ns]

# %%
df_property_1["PRICE"].loc[between_final].describe()
# Out:
# count    2.697600e+04
# mean     2.022352e+05
# std      9.046649e+05
# min      0.000000e+00
# 25%      5.000000e+03
# 50%      1.250000e+05
# 75%      2.350000e+05
# max      1.120000e+08
# Name: PRICE, dtype: float64

# %%
df_property_1["PRICE"].loc[between_init].describe()
# Out:
# count    3.382200e+04
# mean     1.370707e+05
# std      6.440108e+05
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      4.500000e+04
# 75%      1.500000e+05
# max      4.800000e+07
# Name: PRICE, dtype: float64

# %%
df_property_1["PRICE"].describe()
# Out:
# count    3.077560e+05
# mean     1.725544e+05
# std      9.698147e+05
# min      0.000000e+00
# 25%      6.990000e+02
# 50%      7.800000e+04
# 75%      1.849000e+05
# max      1.487529e+08
# Name: PRICE, dtype: float64
