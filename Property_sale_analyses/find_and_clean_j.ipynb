# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_property = pd.read_csv('property_sales.csv')
# Out:
# C:\Users\jahli\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_property.isnull()
# Out:
#         PARID  PROPERTYHOUSENUM  PROPERTYFRACTION  PROPERTYADDRESSDIR  \
# 0       False             False             False                True
# 1       False             False             False                True
# 2       False             False             False                True
# 3       False             False             False                True
# 4       False             False             False                True
# ...       ...               ...               ...                 ...
# 307751  False             False             False                True
# 307752  False             False             False                True
# 307753  False             False             False                True
# 307754  False             False             False                True
# 307755  False             False             False                True
#
#         PROPERTYADDRESSSTREET  PROPERTYADDRESSSUF  PROPERTYADDRESSUNITDESC  \
# ...

# %%
cleaned = df_property.dropna()

# %%
cleaned.duplicated()
# Out:
# 572       False
# 862       False
# 893       False
# 1458      False
# 3291      False
#           ...
# 306339    False
# 306540    False
# 306934    False
# 307163    False
# 307728    False
# Length: 859, dtype: bool

# %%
wb.save('property_sales.csv')

# %%
df_property.isnull()
# Out:
#         PARID  PROPERTYHOUSENUM  PROPERTYFRACTION  PROPERTYADDRESSDIR  \
# 0       False             False             False                True
# 1       False             False             False                True
# 2       False             False             False                True
# 3       False             False             False                True
# 4       False             False             False                True
# ...       ...               ...               ...                 ...
# 307751  False             False             False                True
# 307752  False             False             False                True
# 307753  False             False             False                True
# 307754  False             False             False                True
# 307755  False             False             False                True
#
#         PROPERTYADDRESSSTREET  PROPERTYADDRESSSUF  PROPERTYADDRESSUNITDESC  \
# ...

# %%
cleaned
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 572     0084P00171000200             384.0
# 862     0084K00298020300             333.0
# 893     0052E00033005400             552.0
# 1458    0052E00011030200             128.0
# 3291    0085A00168000600             724.0
# ...                  ...               ...              ...
# 306339  0160J00060030100             227.0
# 306540  0084K00314010300             363.0
# 306934  0027H00144008300             166.0
# 307163  0027H00117070400             220.0
# 307728  0052A00183020500             425.0
#
#        PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 572                     S              HIGHLAND                AVE
# 862                     S              HIGHLAND                AVE
# 893                     N               NEVILLE                 ST
# 1458                    N                 CRAIG                 ST
# 3291                    S                NEGLEY                AVE
# ...

# %%
cleaned.to_excel("cleaned_property_sales.xlsx",
             sheet_name='Sheet_name_1')

# %%
df_property2 = pd.read_excel("cleaned_property_sales.xlsx")

# %%
df_property2.isnull()
# Out:
#      Unnamed: 0  PARID  PROPERTYHOUSENUM  PROPERTYFRACTION  \
# 0         False  False             False             False
# 1         False  False             False             False
# 2         False  False             False             False
# 3         False  False             False             False
# 4         False  False             False             False
# ..          ...    ...               ...               ...
# 854       False  False             False             False
# 855       False  False             False             False
# 856       False  False             False             False
# 857       False  False             False             False
# 858       False  False             False             False
#
#      PROPERTYADDRESSDIR  PROPERTYADDRESSSTREET  PROPERTYADDRESSSUF  \
# 0                 False                  False               False
# 1                 False                  False               False
# ...

# %%
df_property["PROPERTYADDRESSUNITDESC"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 307751    NaN
# 307752    NaN
# 307753    NaN
# 307754    NaN
# 307755    NaN
# Name: PROPERTYADDRESSUNITDESC, Length: 307756, dtype: object

# %%
cleaned = df_property.dropna(axis = 1, how = 'all')

# %%
cleaned
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 0       1075F00108000000            4720.0
# 1       0011A00237000000               0.0
# 2       0011J00047000000            1903.0
# 3       0113B00029000000             479.0
# 4       0119S00024000000            5418.0
# ...                  ...               ...              ...
# 307751  0424D00020000000               0.0
# 307752  0115B00050000000             466.0
# 307753  0028P00027000000             300.0
# 307754  0613B00301000000            1230.0
# 307755  0383B00358000000             901.0
#
#        PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 0                     NaN             HIGHPOINT                 DR
# 1                     NaN               LOMBARD                 ST
# 2                     NaN                FORBES                AVE
# 3                     NaN             ROOSEVELT                AVE
# 4                     NaN              CARNEGIE                 ST
# ...

# %%
cleaned.notnull()
# Out:
#         PARID  PROPERTYHOUSENUM  PROPERTYFRACTION  PROPERTYADDRESSDIR  \
# 0        True              True              True               False
# 1        True              True              True               False
# 2        True              True              True               False
# 3        True              True              True               False
# 4        True              True              True               False
# ...       ...               ...               ...                 ...
# 307751   True              True              True               False
# 307752   True              True              True               False
# 307753   True              True              True               False
# 307754   True              True              True               False
# 307755   True              True              True               False
#
#         PROPERTYADDRESSSTREET  PROPERTYADDRESSSUF  PROPERTYADDRESSUNITDESC  \
# ...

# %%
df_property["PRICE"].isnull()
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 438     8870X11920000089              22.0
# 667     0311K00400042A00              42.0                A
# 668     0311K00400042B00              42.0                B
# 669     9870X11082000000              19.0
# 670     8870X12250000000              20.0
# ...                  ...               ...              ...
# 307521  8000T04751000000              61.0
# 307539  0662B00003000000            1216.0
# 307557  0536K00363000000            6359.0
# 307628  0922L00001SE1300               0.0
# 307666  8000T02964000000             242.0
#
#        PROPERTYADDRESSDIR     PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 438                   NaN  ALLEGHENY COUNTY AIRPORT                NaN
# 667                   NaN  ALLEGHENY COUNTY AIRPORT                NaN
# 668                   NaN  ALLEGHENY COUNTY AIRPORT                NaN
# 669                   NaN  ALLEGHENY COUNTY AIRPORT                NaN
# ...

# %%
x = df_property["PRICE"].isnull().sum()

# %%
correct_mean = SimpleImputer(missing_values=np.NaN, strategy = 'mean')

# %%
x
# Out:
# 2478

# %%
df_property["PRICE"].sum()
# Out:
# 52677069521.0

# %%
x = df_property["PRICE"].isnull()

# %%
x
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 307751    False
# 307752    False
# 307753    False
# 307754    False
# 307755    False
# Name: PRICE, Length: 307756, dtype: bool

# %%
df_property["PRICE"].fillna(df_property["PRICE"].mean)
# Out:
# 0          120000.0
# 1            1783.0
# 2            4643.0
# 3               0.0
# 4           27541.0
#             ...
# 307751          1.0
# 307752     160000.0
# 307753    4350000.0
# 307754     229000.0
# 307755      95000.0
# Name: PRICE, Length: 307756, dtype: object

# %%
df_property["PRICE"].isnull().sum()
# Out:
# 2478

# %%
mean = df_property['PRICE'].mean()

# %%
mean
# Out:
# 172554.42423299418

# %%
df_property["PRICE"].count()
# Out:
# 305278

# %%
df_property["PRICE"].sum()
# Out:
# 52677069521.0

# %%
df_property["PRICE"].fillna(value=df_property["PRICE"].mean(), inplace=True)

# %%
df_property["PRICE"].isnull().sum()
# Out:
# 0

# %%
df_property["SALEDATE"].isnull().count()
# Out:
# 307756

# %%
df_property["SALEDATE"]
# Out:
# 0         2012-09-27
# 1         2015-01-06
# 2         2012-10-26
# 3         2017-03-06
# 4         2015-02-04
#              ...
# 307751    2019-05-30
# 307752    2019-05-10
# 307753    2019-05-22
# 307754    2019-05-15
# 307755    2019-04-04
# Name: SALEDATE, Length: 307756, dtype: object

# %%
df_property["SALEDATE"] = "nan"

# %%
df_property["SALEDATE"] = pd.to_datetime(df_property["SALEDATE"])

# %%
df_property["SALEDATE"]
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 307751   NaT
# 307752   NaT
# 307753   NaT
# 307754   NaT
# 307755   NaT
# Name: SALEDATE, Length: 307756, dtype: datetime64[ns]

# %%
df_property = pd.read_csv('property_sales.csv')
# Out:
# C:\Users\jahli\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_property["SALEDATE"]
# Out:
# 0         2012-09-27
# 1         2015-01-06
# 2         2012-10-26
# 3         2017-03-06
# 4         2015-02-04
#              ...
# 307751    2019-05-30
# 307752    2019-05-10
# 307753    2019-05-22
# 307754    2019-05-15
# 307755    2019-04-04
# Name: SALEDATE, Length: 307756, dtype: object

# %%
df_property["PRICE"].fillna(value=df_property["PRICE"].mean(), inplace=True)

# %%
df_property["PRICE"].isnull().sum()
# Out:
# 0

# %%
df_property["SALEDATE"].sort_values(ascending=True)
# Out:
# 29810     2012-01-01
# 12258     2012-01-01
# 671       2012-01-01
# 670       2012-01-01
# 669       2012-01-01
#              ...
# 255444    2020-11-16
# 291157    2020-11-16
# 257246    2020-11-19
# 295358    2020-11-19
# 279904    2020-11-23
# Name: SALEDATE, Length: 307756, dtype: object

# %%
df_property["PROPERTYCITY"]
# Out:
# 0            GIBSONIA
# 1          PITTSBURGH
# 2          PITTSBURGH
# 3          PITTSBURGH
# 4          PITTSBURGH
#              ...
# 307751      SEWICKLEY
# 307752     PITTSBURGH
# 307753     PITTSBURGH
# 307754     PITTSBURGH
# 307755    MC KEESPORT
# Name: PROPERTYCITY, Length: 307756, dtype: object

# %%
df_property["PROPERTYCITY"].isnull().sum()
# Out:
# 1

# %%
df_property["PROPERTYCITY"].sort_values(ascending = True)
# Out:
# 57148     ALLISON PARK
# 156236    ALLISON PARK
# 266760    ALLISON PARK
# 266785    ALLISON PARK
# 9493      ALLISON PARK
#               ...
# 288800      WILMERDING
# 38975       WILMERDING
# 213967      WILMERDING
# 217929         WITAKER
# 187923             NaN
# Name: PROPERTYCITY, Length: 307756, dtype: object

# %%
df_property["SCHOOLDESC"].sort_values(ascending = True)
# Out:
# 271148    Allegheny Valley
# 298618    Allegheny Valley
# 279241    Allegheny Valley
# 279250    Allegheny Valley
# 39305     Allegheny Valley
#                 ...
# 45349       Woodland Hills
# 68398       Woodland Hills
# 241089      Woodland Hills
# 109588      Woodland Hills
# 18359       Woodland Hills
# Name: SCHOOLDESC, Length: 307756, dtype: object

# %%
df_property["PROPERTYCITY"].dropna().count()
# Out:
# 307755

# %%
df_property.to_csv("cleaned1_property_sales.csv")

# %%
df_property["PROPERTYCITY"]
# Out:
# 0            GIBSONIA
# 1          PITTSBURGH
# 2          PITTSBURGH
# 3          PITTSBURGH
# 4          PITTSBURGH
#              ...
# 307751      SEWICKLEY
# 307752     PITTSBURGH
# 307753     PITTSBURGH
# 307754     PITTSBURGH
# 307755    MC KEESPORT
# Name: PROPERTYCITY, Length: 307756, dtype: object

# %%
df_property.drop(["PROPERTyCITY"], axis=1)
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 0       1075F00108000000            4720.0
# 1       0011A00237000000               0.0
# 2       0011J00047000000            1903.0
# 3       0113B00029000000             479.0
# 4       0119S00024000000            5418.0
# ...                  ...               ...              ...
# 307751  0424D00020000000               0.0
# 307752  0115B00050000000             466.0
# 307753  0028P00027000000             300.0
# 307754  0613B00301000000            1230.0
# 307755  0383B00358000000             901.0
#
#        PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 0                     NaN             HIGHPOINT                 DR
# 1                     NaN               LOMBARD                 ST
# 2                     NaN                FORBES                AVE
# 3                     NaN             ROOSEVELT                AVE
# 4                     NaN              CARNEGIE                 ST
# ...

# %%
df_property
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 0       1075F00108000000            4720.0
# 1       0011A00237000000               0.0
# 2       0011J00047000000            1903.0
# 3       0113B00029000000             479.0
# 4       0119S00024000000            5418.0
# ...                  ...               ...              ...
# 307751  0424D00020000000               0.0
# 307752  0115B00050000000             466.0
# 307753  0028P00027000000             300.0
# 307754  0613B00301000000            1230.0
# 307755  0383B00358000000             901.0
#
#        PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 0                     NaN             HIGHPOINT                 DR
# 1                     NaN               LOMBARD                 ST
# 2                     NaN                FORBES                AVE
# 3                     NaN             ROOSEVELT                AVE
# 4                     NaN              CARNEGIE                 ST
# ...

# %%
df_property['PRICE']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 307751    0
# 307752    0
# 307753    0
# 307754    0
# 307755    0
# Name: PRICE, Length: 307756, dtype: int64

# %%
df_property_1 = pd.read_csv("cleaned1_property_sales.csv")
# Out:
# C:\Users\jahli\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_property_1['PRICE'] == 0
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 307751    False
# 307752    False
# 307753    False
# 307754    False
# 307755    False
# Name: PRICE, Length: 307756, dtype: bool

# %%
df_property_1['PRICE'].describe()
# Out:
# count    3.077560e+05
# mean     1.725544e+05
# std      9.698147e+05
# min      0.000000e+00
# 25%      6.990000e+02
# 50%      7.800000e+04
# 75%      1.849000e+05
# max      1.487529e+08
# Name: PRICE, dtype: float64

# %%
col_p = df_property_1['PRICE']

# %%
col_p[np.abs(col_p) > 688].sort_values(ascending = True)
# Out:
# 62501           696.0
# 127945          700.0
# 276257          700.0
# 266598          700.0
# 233762          700.0
#              ...
# 239863     71200000.0
# 174240     81325000.0
# 287804    112000000.0
# 53356     124400000.0
# 135243    148752900.0
# Name: PRICE, Length: 230818, dtype: float64

# %%
 sns.distplot(col_p, bins=40, color='k')
# Out:
# C:\Users\jahli\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PRICE', ylabel='Density'>

# %%
col_p.count()
# Out:
# 307756

# %%
print(col_p)
# Out:
# 0          120000.0
# 1            1783.0
# 2            4643.0
# 3               0.0
# 4           27541.0
#             ...
# 307751          1.0
# 307752     160000.0
# 307753    4350000.0
# 307754     229000.0
# 307755      95000.0
# Name: PRICE, Length: 307756, dtype: float64

# %%
df_property_1[["PRICE", "PROPERTYCITY"]]
# Out:
#             PRICE PROPERTYCITY
# 0        120000.0     GIBSONIA
# 1          1783.0   PITTSBURGH
# 2          4643.0   PITTSBURGH
# 3             0.0   PITTSBURGH
# 4         27541.0   PITTSBURGH
# ...           ...          ...
# 307751        1.0    SEWICKLEY
# 307752   160000.0   PITTSBURGH
# 307753  4350000.0   PITTSBURGH
# 307754   229000.0   PITTSBURGH
# 307755    95000.0  MC KEESPORT
#
# [307756 rows x 2 columns]

# %%
price_city = df_property_1[["PRICE","PROPERTYCITY"]]

# %%
df_property_1[df_property_1["PROPERTYCITY"] == "PITTSBURGH"]
# Out:
#         Unnamed: 0             PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 1                1  0011A00237000000               0.0
# 2                2  0011J00047000000            1903.0
# 3                3  0113B00029000000             479.0
# 4                4  0119S00024000000            5418.0
# 5                5  0120D00075000000            6311.0
# ...            ...               ...               ...              ...
# 307748      307748  0175P00267000000             209.0
# 307749      307749  0249B002450C2500             349.0
# 307752      307752  0115B00050000000             466.0
# 307753      307753  0028P00027000000             300.0
# 307754      307754  0613B00301000000            1230.0
#
#        PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# 1                     NaN               LOMBARD                 ST
# 2                     NaN                FORBES                AVE
# ...
